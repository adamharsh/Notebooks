# %%
# Weighted moving average with auti weight selection

# %%
import pandas as pd
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3d2463a0-482f-4df0-bc6b-967505216a9a" name="files[]" multiple disabled />
#      <output id="result-3d2463a0-482f-4df0-bc6b-967505216a9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test (4).csv
# ...

# %%
x=pd.read_csv('test.csv')
x.head()
# Out:
#         Date   Price
# 0  10/1/2017  3.5300
# 1  9/24/2017  3.5070
# 2  9/17/2017  3.5425
# 3  9/10/2017  3.5690
# 4   9/3/2017  3.5125

# %%
T=len(x['Date'])
m=((T)*(T+1))/2
st=0
for i in range(T-1,0,-1):
  st+=((i/m)*x['Price'][T-i])

# %%
print(st)
# Out:
# 4.430733350174892
