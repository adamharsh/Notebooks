/2015,4.8177\r\n19/04/2015,4.7493\r\n26/04/2015,4.70606\r\n3/5/2015,4.54544\r\n10/5/2015,4.51746\r\n17/05/2015,4.52054\r\n24/05/2015,4.5162\r\n31/05/2015,4.40294\r\n7/6/2015,4.4658\r\n14/06/2015,4.47264\r\n21/06/2015,4.41104\r\n28/06/2015,4.62316\r\n5/7/2015,5.14284\r\n12/7/2015,5.25518\r\n19/07/2015,5.29672\r\n26/07/2015,4.96126\r\n2/8/2015,4.60172\r\n9/8/2015,4.57944\r\n16/08/2015,4.59388\r\n23/08/2015,4.5458\r\n30/08/2015,4.52536\r\n6/9/2015,4.41172\r\n13/09/2015,4.47366\r\n20/09/2015,4.6336\r\n27/09/2015,4.61374\r\n4/10/2015,4.67146\r\n11/10/2015,4.71354\r\n18/10/2015,4.55962\r\n25/10/2015,4.54098\r\n1/11/2015,4.57646\r\n8/11/2015,4.52896\r\n15/11/2015,4.3522\r\n22/11/2015,4.3552\r\n29/11/2015,4.38224\r\n6/12/2015,4.42634\r\n13/12/2015,4.43168\r\n20/12/2015,4.43344\r\n27/12/2015,4.3354\r\n3/1/2016,4.254175\r\n10/1/2016,4.17946\r\n17/01/2016,4.22024\r\n24/01/2016,4.33894\r\n31/01/2016,4.35666\r\n7/2/2016,4.36968\r\n14/02/2016,4.26216\r\n21/02/2016,4.30292\r\n28/02/2016,4.26634\r\n6/3/2016,4.17682\r\n13/03/2016,4.22244\r\n20/03/2016,4.30318\r\n27/03/2016,4.322175\r\n3/4/2016,4.24816\r\n10/4/2016,4.19494\r\n17/04/2016,4.31896\r\n24/04/2016,4.48092\r\n1/5/2016,4.47836\r\n8/5/2016,4.38654\r\n15/05/2016,4.40212\r\n22/05/2016,4.55752\r\n29/05/2016,4.6701\r\n5/6/2016,4.77004\r\n12/6/2016,4.93232\r\n19/06/2016,4.98604\r\n26/06/2016,4.58118\r\n3/7/2016,4.30404\r\n10/7/2016,3.9943\r\n17/07/2016,4.04738\r\n24/07/2016,3.89738\r\n31/07/2016,3.82016\r\n7/8/2016,3.7 ...

# %%
import pandas as pd
from pandas import datetime
from matplotlib import pyplot
 
def parser(x):
	return datetime.strptime(''+x, '%m/%d/%Y')
 
series = pd.read_csv('test.csv',header=None,parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
print(series.head())
series.plot()
pyplot.show()
# Out:
# 0
# 2013-01-06    7.794975
# 2013-01-13    7.863400
# 2013-01-20    8.234920
# 2013-01-27    8.186260
# 2013-02-03    8.317480
# Name: 1, dtype: float64

# %%
from pandas.tools.plotting import autocorrelation_plot
autocorrelation_plot(series)
pyplot.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(series,order=(2,1,0))
# model_fit = model.fit(disp=0)
# print(model_fit.summary())
# # plot residual errors
# residuals = DataFrame(model_fit.resid)
# residuals.plot()
# pyplot.show()
# residuals.plot(kind='kde')
# pyplot.show()
# print(residuals.describe())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-6b9e504622bb> in <module>()
#       1 from statsmodels.tsa.arima_model import ARIMA
# ----> 2 model = ARIMA(series,order=(2,1,0))
#       3 # model_fit = model.fit(disp=0)
#       4 # print(model_fit.summary())
#       5 # # plot residual errors
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#     998         else:
#     999             mod = super(ARIMA, cls).__new__(cls)
# -> 1000             mod.__init__(endog, order, exog, dates, freq, missing)
#    1001             return mod
#    1002
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#    1022             self.exog = self.exog[d:]
#    1023         if d == 1:
# -> 1024             self.data.ynames = 'D.' + self.endog_names
#    1025         else:
#    1026             self.data.ynames = 'D{0:d}.'.format(d) + self.endog_names
#
# TypeError: must be str, not numpy.int64
